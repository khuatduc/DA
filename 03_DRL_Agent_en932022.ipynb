# %% [markdown]
# ## Tutorial 3: Demonstration of developing original *Agent* with DRL
# This tutorial demonstrate how to develop *Agent* with DRL algorithm by using ***KSPDRLAgent*** .
#
# *Agent* base classes are as follows:
#
# - `Agent`(used in **Tutorial 2**)
# - `KSPAgent`(used in **Tutorial 2**)
# - `PrioritizedKSPAgent`(used in **Tutorial 2**)
# - `KSPDRLAgent`

# %%
# !pip install git+https://github.com/Optical-Networks-Group/rsa-rl.git
# Out:
# Collecting git+https://github.com/Optical-Networks-Group/rsa-rl.git
#   Cloning https://github.com/Optical-Networks-Group/rsa-rl.git to c:\users\admini~1\appdata\local\temp\2\pip-req-build-v6g5zwwj
#   Resolved https://github.com/Optical-Networks-Group/rsa-rl.git to commit 4b82c519742fa47b1537204780174cdb0c2f4ae0
# Requirement already satisfied: bitarray>=1.2.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (2.4.0)
# Requirement already satisfied: networkx>=2.5 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (2.6.3)
# Requirement already satisfied: tensorboard>=2.2.2 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (2.7.0)
# Requirement already satisfied: tensorboardX>=2.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (2.5)
# Requirement already satisfied: torch>=1.5.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (1.10.2)
# Requirement already satisfied: plotly>=4.9.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (5.6.0)
# Requirement already satisfied: dash>=1.14.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (2.2.0)
# Requirement already satisfied: dash-bootstrap-components>=0.10.7 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (1.0.3)
# Requirement already satisfied: pfrl>=0.1.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from rsarl==1.0.0) (0.3.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from dash>=1.14.0->rsarl==1.0.0) (2.0.0)
# Requirement already satisfied: flask-compress in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from dash>=1.14.0->rsarl==1.0.0) (1.11)
# Requirement already satisfied: dash-table==5.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from dash>=1.14.0->rsarl==1.0.0) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from dash>=1.14.0->rsarl==1.0.0) (2.0.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from dash>=1.14.0->rsarl==1.0.0) (2.0.3)
# Requirement already satisfied: Jinja2>=3.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (3.0.3)
# Requirement already satisfied: Werkzeug>=2.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (2.0.2)
# Requirement already satisfied: click>=7.1.2 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (8.0.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (2.1.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (4.8.2)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from click>=7.1.2->Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from Jinja2>=3.0->Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (2.1.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pfrl>=0.1.0->rsarl==1.0.0) (3.6.0)
# Requirement already satisfied: gym>=0.9.7 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pfrl>=0.1.0->rsarl==1.0.0) (0.19.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pfrl>=0.1.0->rsarl==1.0.0) (8.4.0)
# Requirement already satisfied: numpy>=1.10.4 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pfrl>=0.1.0->rsarl==1.0.0) (1.21.4)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from gym>=0.9.7->pfrl>=0.1.0->rsarl==1.0.0) (1.6.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from plotly>=4.9.0->rsarl==1.0.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from plotly>=4.9.0->rsarl==1.0.0) (8.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (2.3.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (1.42.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (0.37.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (59.3.0)
# Requirement already satisfied: absl-py>=0.4 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from tensorboard>=2.2.2->rsarl==1.0.0) (3.19.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.2->rsarl==1.0.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.2->rsarl==1.0.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.2->rsarl==1.0.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.2->rsarl==1.0.0) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata->click>=7.1.2->Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from importlib-metadata->click>=7.1.2->Flask>=1.0.4->dash>=1.14.0->rsarl==1.0.0) (4.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.2->rsarl==1.0.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.2->rsarl==1.0.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.2->rsarl==1.0.0) (2.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.2->rsarl==1.0.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard>=2.2.2->rsarl==1.0.0) (3.3)
#   Running command git clone -q https://github.com/Optical-Networks-Group/rsa-rl.git 'C:\Users\ADMINI~1\AppData\Local\Temp\2\pip-req-build-v6g5zwwj'
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.2->rsarl==1.0.0) (3.1.1)
# Requirement already satisfied: brotli in c:\programdata\anaconda3\envs\myenv\lib\site-packages (from flask-compress->dash>=1.14.0->rsarl==1.0.0) (1.0.9)

# %% [markdown]
# ## Evaluation Settings
# For evaluation, prepare *Environment* and evaluation function.
# Please see **Tutorial 1** if you have not seen it.

# %%
import functools
import numpy as np

from rsarl.envs import DeepRMSAEnv, make_multiprocess_vector_env
from rsarl.requester import UniformRequester
from rsarl.networks import SingleFiberNetwork
from rsarl.evaluator import batch_warming_up, batch_evaluation, batch_summary
    # exp settings
_file = open('result2.csv', 'w')
avg_request_arrival_rate=0.6
while(avg_request_arrival_rate<=1.6):
    n_requests = 10000
    n_envs, seed = 30, 0

    # build network
    net = SingleFiberNetwork("nsf", n_slot=80, is_weight=True)
    # build requester
    requester = UniformRequester(
        net.n_nodes,
        avg_service_time=100,
        avg_request_arrival_rate=avg_request_arrival_rate)
    # build env
    env = DeepRMSAEnv(net, requester)
    # envs for training and evaluation
    envs = make_multiprocess_vector_env(env, n_envs, seed, test=False)
    test_envs = make_multiprocess_vector_env(env, n_envs, seed, test=True)
    def _evaluation(envs, agent, n_requests): 
        # start simulation
        envs.reset()
        # 
        batch_warming_up(envs, agent, n_requests=3000)
        # evaluation
        experiences = batch_evaluation(envs, agent, n_requests=n_requests)
        # calc performance
        blocking_probs, avg_utils, total_rewards = batch_summary(experiences)

        for env_id, (blocking_prob, avg_util, total_reward) in enumerate(zip(blocking_probs, avg_utils, total_rewards)):
            print(f'[{env_id}-th ENV]Blocking Probability: {blocking_prob}')
            print(f'[{env_id}-th ENV]Avg. Slot-utilization: {avg_util}')
            print(f'[{env_id}-th ENV]Total Rewards: {total_reward}')
            _file.write(str(n_envs)+","+str(avg_request_arrival_rate)+","+str(env_id)+","+str(blocking_prob)+","+str(avg_util)+","+str(total_reward)+"\n");
            
    # evaluation with test environments
    evaluation = functools.partial(_evaluation, envs=test_envs, n_requests=n_requests)
    import pfrl
    import torch
    import torch.nn as nn
    class DeepRMSAv1_DNN(torch.nn.Module):

        def __init__(self, SLOT: int, ICH: int, K: int, n_edges: int):
            super().__init__()
            self.SLOT = SLOT
            # CNN
            self.conv = nn.Sequential(*[
                nn.Conv2d(ICH, 1, kernel_size=(1,1), stride=(1, 1)),
                nn.ReLU(),
                # 2 conv layers with16 filters
                nn.Conv2d(1, 16, kernel_size=(n_edges,1), stride=(1, 1)),
                nn.ReLU(),
                nn.Conv2d(16, 16, kernel_size=(1,1), stride=(1, 1)),
                nn.ReLU(),
                # 2 depthwise conv layers with 1 filter
                nn.ZeroPad2d((1, 0, 0, 0)), # left, right, top, bottom
                nn.Conv2d(16, 16, kernel_size=(1,2), stride=(1, 1), groups=16),
                nn.ReLU(),
                nn.ZeroPad2d((1, 0, 0, 0)),
                nn.Conv2d(16, 16, kernel_size=(1,2), stride=(1, 1), groups=16),
                nn.ReLU(),
            ])
            # fc
            self.fc = nn.Sequential(*[
                nn.Linear(SLOT*16, 128),
                nn.ReLU(),
                nn.Linear(128, 50),
                nn.ReLU(),
                nn.Linear(50, K),
            ])      

        def forward(self, x):
            h = x
            h = self.conv(h)
            h = h.view(-1, self.SLOT*16)
            h = self.fc(h)
            return pfrl.action_value.DiscreteActionValue(h)
    # Experimental Settings
    K = 5
    # slot-table(1) + one-hot-node * 2 + bandwidth(1)
    ICH = 1 + 2 * net.n_nodes + 1
    # build DNN for Q-function
    q_func = DeepRMSAv1_DNN( net.n_slot, ICH, K, net.n_edges)
    # Specify optimizer 
    optimizer = torch.optim.Adam(q_func.parameters(), eps=1e-2)
    def _action_sampler(k):
        return np.random.randint(0, k)

    # random action function
    action_sampler = functools.partial(_action_sampler, k=K)
    # Set the discount factor that discounts future rewards.
    gamma = 0.99

    # Use epsilon-greedy for exploration
    explorer = pfrl.explorers.ConstantEpsilonGreedy(
        epsilon=0.1, random_action_func=action_sampler)

    # DQN uses Experience Replay.
    # Specify a replay buffer and its capacity.
    replay_buffer = pfrl.replay_buffers.ReplayBuffer(capacity=10 ** 6, num_steps=50)
    # Now create an agent that will interact with the environment.
    DDQN = pfrl.agents.DoubleDQN(
        q_func,
        optimizer,
        replay_buffer,
        gamma,
        explorer,
        minibatch_size=50,
        update_interval=1,
        replay_start_size=500,
        target_update_interval=100,
    
    )
    import numpy as np
    import networkx as nx
    from rsarl.data import Action
    from rsarl.agents import KSPDRLAgent
    from rsarl.utils import cal_slot, sort_tuple
    from rsarl.algorithms import SpectrumAssignment
    def vectorize(n_nodes: int, node_id: int):
        mp = np.eye(n_nodes, dtype=np.float32)[node_id].reshape(-1, 1, 1)
        return mp

    class DRLAgent(KSPDRLAgent):

        def preprocess(self, obs):
            """
            """
            net = obs.net
            source, destination, bandwidth, duration = obs.request
            # slot table
            whole_slot = np.array(list(nx.get_edge_attributes(net.G, name="slot").values()))
            whole_slot = whole_slot.reshape(1, net.n_edges, net.n_slot).astype(np.float32)
            # source, destination, bandwidth map
            smap = np.ones_like(whole_slot) * vectorize(net.n_nodes, source)
            dmap = np.ones_like(whole_slot) * vectorize(net.n_nodes, destination)
            bmap = np.ones_like(whole_slot) * bandwidth
            # concate: (1, ICH, #edges, #slots)
            fvec = np.concatenate([whole_slot, smap, dmap, bmap], axis=0)
            return fvec.astype(np.float32, copy=False)

        def map_drlout_to_action(self, obs, out):
            net = obs.net
            s, d, bandwidth, duration = obs.request
            paths = self.path_table[sort_tuple((s, d))]
            # map
            path = paths[out]

            #required slots
            path_len = net.distance(path)
            n_req_slot = cal_slot(bandwidth, path_len)
            #FF
            path_slot = net.path_slot(path)
            slot_index = SpectrumAssignment.first_fit(path_slot, n_req_slot)
            if slot_index is None:
                return None
            else:
                return Action(path, slot_index, n_req_slot, duration)
    agent = DRLAgent(k=5, drl=DDQN)
    # prepare path table
    agent.prepare_ksp_table(net)
    # Batch act
    obses = envs.reset()
    resets = [False for _ in range(len(obses))]
    for train_cnt in range(200000):
        acts = agent.batch_act(obses)
        obses, rews, dones, infos = envs.step(acts)
        agent.batch_observe(obses, rews, dones, resets)

        # Make mask(not_end). 0 if done/reset, 1 if pass
        not_end = np.logical_not(dones)
        obses = envs.reset(not_end)
    
        if train_cnt % 20000 == 0:
            print(f'[{train_cnt}-th EVAL]')
            test_envs.reset()
            with agent.drl.eval_mode():
                evaluation(agent=agent)
    avg_request_arrival_rate=avg_request_arrival_rate+0.1;
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\2\ipykernel_5004\816313225.py in <module>
#      23     env = DeepRMSAEnv(net, requester)
#      24     # envs for training and evaluation
# ---> 25     envs = make_multiprocess_vector_env(env, n_envs, seed, test=False)
#      26     test_envs = make_multiprocess_vector_env(env, n_envs, seed, test=True)
#      27     def _evaluation(envs, agent, n_requests):
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\site-packages\rsarl\envs\multiprocess_vector_env.py in make_multiprocess_vector_env(env, n_env, base_seed, test)
#      72         [
#      73             functools.partial(make_env, env, process_seeds[idx], test)
# ---> 74             for idx in range(n_env)
#      75         ]
#      76     )
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\site-packages\rsarl\envs\multiprocess_vector_env.py in __init__(self, env_fns)
#      54         ]
#      55         for p in self.ps:
# ---> 56             p.start()
#      57         self.last_obs = [None] * self.num_envs
#      58         self.closed = False
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      87             try:
#      88                 reduction.dump(prep_data, to_child)
# ---> 89                 reduction.dump(process_obj, to_child)
#      90             finally:
#      91                 set_spawning_popen(None)
#
# C:\ProgramData\Anaconda3\envs\MyEnv\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# KeyboardInterrupt:

# %% [markdown]
# ## Step1: Select DRL algorithm from PFRL
# *RSA-RL* assumes that DRL algorithm provided by [PFRL](https://github.com/pfnet/pfrl) library is used.
# ***PFRL*** is a DRL library that implements various state-of-the-art deep reinforcement algorithms in Python using[PyTorch](https://github.com/pytorch/pytorch).
# Discrete action algorithms are as follows:
#
# - ***DQN(Double DQN)***
# - ***Rainbow***
# - ***IQN***
# - ***A3C***, ***A2C***
# - ***ACER***
# - ***PPO***
# - ***TRPO***
#
# In this tutorial, we try to reproduct the prior [DeepRMSA](https://ieeexplore.ieee.org/document/8386173) that applies DRL to ***routing algorithm*** that selects one from the *k* shortest paths.
# This tutorial call it ***DeepRMSAv1***, and implement it by using ***Double DQN (DDQN)***.
# In the case of using DDQN, there are three steps:
#
# 1. Build  deep neural network (DNN) model
# 2. Specify ***Explore*** and ***Replay Buffer***, e.g., epsilon greedy and prioritized replay buffer, respectively
# 3. Build DDQN
#
# First, you develop a DNN that the number of outputs is *k*.

# %% [markdown]
# ### Specify *Explore* and *Replay Buffer*
# This tutorial selects ConstantEpsilonGreedy.
# If you want to use others, please refere *PFRL*'s documentation:
# - [explore](https://pfrl.readthedocs.io/en/latest/explorers.html)
# - [replay buffer](https://pfrl.readthedocs.io/en/latest/replay_buffers.html)

# %% [markdown]
# ## Step 2: Develop your algorithm by using *KSPDRLAgent*
# *RSA-RL* provides ***KSPDRLAgent*** that is based on *KSPAgent* class, which means that ***k-shortest path table***  can be used.
# You need to override two methods:
# - `preprocess`: create *feature vector* from *observation*
# - `map_drlout_to_action`: map outputs of DRL algorithms to *Action*

# %% [markdown]
# ## Step 3: Training and Evaluate *DRL Agent*
# Finally, let's training and evaluation!
# Interaction between *Agent* with *Environment* automatically trains *Agent*.
# NOTE that before evaluation, you should change DRL model to ***evaluation mode*** by `eval_mode` method that *explore* does not run.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# That's all!
# This tutorial demonstrates how to develop DRL *Agent*.
# Next tutorial demonstrate how to develop your own ***Environment***.
